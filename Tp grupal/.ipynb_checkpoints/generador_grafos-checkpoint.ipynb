# %% [markdown]
# ## Analisis cantidad por centro

# %%
import numpy as np
import matplotlib.pyplot as plt
fracuencias = []
with open("cant_centros_reducido.txt") as frecuencia_centros:
    frecuencias = []
    for linea in frecuencia_centros:
        cantidad = linea.split(",")[1]
        frecuencias.append(cantidad)

plt.bar(np.arange(30), np.array(frecuencias))
plt.show()

# %%
import pandas as pd
import seaborn as sns

# %%
centro_por_votante = pd.read_csv("bivalente_encendidas_reducido.csv")

# %%
centro_por_votante.head()
# Out:
#    id_votante  id_centro
# 0           1         20
# 1           2         18
# 2           3         14
# 3           4         25
# 4           5          9

# %%
ubicaciones_votantes = pd.read_csv("votantes_reducido.csv")

# %%
ubicaciones_votantes.head()
# Out:
#    id_votante    latitud   longitud
# 0           1 -34.587721 -58.407334
# 1           2 -34.590931 -58.401436
# 2           3 -34.588754 -58.401254
# 3           4 -34.593804 -58.399609
# 4           5 -34.574731 -58.390246

# %%
ubicaciones_centros = pd.read_csv("centros_reducido.csv")

# %%
ubicaciones_centros.head()
# Out:
#    id_centro        lat       long  max_votantes
# 0          1 -34.584847 -58.400357            83
# 1          2 -34.598406 -58.390597           111
# 2          3 -34.590186 -58.392239           226
# 3          4 -34.595953 -58.388593           110
# 4          5 -34.590054 -58.403396           190

# %%
ubicaciones_centros.dtypes
# Out:
# id_centro         int64
# lat             float64
# long            float64
# max_votantes      int64
# dtype: object

# %%
ubicaciones_votantes.dtypes
# Out:
# id_votante      int64
# latitud       float64
# longitud      float64
# dtype: object

# %%
centro_por_votante.dtypes
# Out:
# id_votante    int64
# id_centro     int64
# dtype: object

# %%
votantes = ubicaciones_votantes.set_index('id_votante').join(centro_por_votante.set_index('id_votante'),how='inner').reset_index()
votantes.head()
# Out:
#    id_votante    latitud   longitud  id_centro
# 0           1 -34.587721 -58.407334         20
# 1           2 -34.590931 -58.401436         18
# 2           3 -34.588754 -58.401254         14
# 3           4 -34.593804 -58.399609         25
# 4           5 -34.574731 -58.390246          9

# %%
votantes
# Out:
#       id_votante    latitud   longitud  id_centro
# 0              1 -34.587721 -58.407334         20
# 1              2 -34.590931 -58.401436         18
# 2              3 -34.588754 -58.401254         14
# 3              4 -34.593804 -58.399609         25
# 4              5 -34.574731 -58.390246          9
# 5              6 -34.588553 -58.387297          9
# 6              7 -34.592400 -58.406108         10
# 7              8 -34.592955 -58.401337         25
# 8              9 -34.595751 -58.400526         30
# 9             10 -34.594951 -58.395593         27
# 10            11 -34.591607 -58.389710          3
# 11            12 -34.597777 -58.387914          4
# 12            13 -34.597393 -58.391785         24
# 13            14 -34.583191 -58.391793          9
# 14            15 -34.585950 -58.385389          9
# 15            16 -34.593090 -58.408025         16
# 16            17 -34.580098 -58.397474          1
# 17            18 -34.583942 -58.402409          8
# 18            19 -34.595143 -58.390632         12
# 19            20 -34.599255 -58.388215         12
# 20            21 -34.593119 -58.393096          3
# 21            22 -34.587056 -58.394120          3
# 22            23 -34.590411 -58.391226          3
# 23            24 -34.572840 -58.392211          9
# 24            25 -34.588601 -58.386416          9
# 25            26 -34.593890 -58.407814         16
# 26            27 -34.588161 -58.408274         20
# 27            28 -34.596342 -58.390702         12
# 28            29 -34.592519 -58.405369         10
# 29            30 -34.584841 -58.391799          9
# ...          ...        ...        ...        ...
# 1104        1105 -34.591567 -58.402984         18
# 1105        1106 -34.593418 -58.405797         10
# 1106        1107 -34.582365 -58.392269          9
# 1107        1108 -34.598194 -58.400650         30
# 1108        1109 -34.572978 -58.391655          9
# 1109        1110 -34.595182 -58.409363         22
# 1110        1111 -34.573856 -58.391968          9
# 1111        1112 -34.589720 -58.401663         14
# 1112        1113 -34.594076 -58.401735         25
# 1113        1114 -34.595696 -58.411787         28
# 1114        1115 -34.592014 -58.408053         16
# 1115        1116 -34.591752 -58.400242         25
# 1116        1117 -34.594786 -58.407890         22
# 1117        1118 -34.591174 -58.391720          3
# 1118        1119 -34.591348 -58.392354          3
# 1119        1120 -34.580700 -58.394126          9
# 1120        1121 -34.586178 -58.402870         14
# 1121        1122 -34.589821 -58.395445          3
# 1122        1123 -34.589827 -58.397017         15
# 1123        1124 -34.571606 -58.382816          9
# 1124        1125 -34.574753 -58.394264          1
# 1125        1126 -34.587681 -58.407224         20
# 1126        1127 -34.596508 -58.408026         22
# 1127        1128 -34.591364 -58.391826          3
# 1128        1129 -34.589220 -58.396429          3
# 1129        1130 -34.597399 -58.399125         30
# 1130        1131 -34.594815 -58.395318         27
# 1131        1132 -34.576663 -58.388270          9
# 1132        1133 -34.596953 -58.393965         24
# 1133        1134 -34.587877 -58.390471          9
#
# [1134 rows x 4 columns]

# %%
ubicaciones_centros['centro'] = True
votantes['centro'] = False

# %%
ubicaciones_centros.head()
# Out:
#    id_centro        lat       long  max_votantes  centro
# 0          1 -34.584847 -58.400357            83    True
# 1          2 -34.598406 -58.390597           111    True
# 2          3 -34.590186 -58.392239           226    True
# 3          4 -34.595953 -58.388593           110    True
# 4          5 -34.590054 -58.403396           190    True

# %%
ubicaciones_centros.head()
# Out:
#    id_centro        lat       long  max_votantes  centro
# 0          1 -34.584847 -58.400357            83    True
# 1          2 -34.598406 -58.390597           111    True
# 2          3 -34.590186 -58.392239           226    True
# 3          4 -34.595953 -58.388593           110    True
# 4          5 -34.590054 -58.403396           190    True

# %%
g = sns.lmplot( x="latitud", y="longitud", data=votantes, fit_reg=False, hue='id_centro', legend=False, height=15)
plt.show()
plt.savefig('votantes_reducido.png', bbox_inches='tight')

# %%
g = sns.lmplot( x="lat", y="long", data=ubicaciones_centros, fit_reg=False, hue='id_centro',markers='x', legend=False, height=15)
plt.savefig('centros_reducido.png', bbox_inches='tight')
plt.show()
